# %% [markdown]
# Part of DEAP Library
#
# Goal is to get exactly $15.05 worth of appetizers, as fast as possible

# %%
import random

# %%
from operator import attrgetter
from collections import Counter

try:
    del Counter.__reduce__
except: pass

import numpy

from deap import algorithms
from deap import base
from deap import creator
from deap import tools

# %% [markdown]
# ## Create Item Dictionary

# %%
ITEMS = {'French Fries': (2.75, 5),
        'Hot Wings' : (3.55, 7),
        'Mixed Fruit' : (2.15, 2),
        'Mozzarella Sticks' : (4.2, 4),
        'Sampler Plate' : (5.8, 10),
        'Side Salad' : (3.35, 3)}
ITEMS_NAME = list(ITEMS.keys())

# %% [markdown]
# ## Fitness Function
#
# Our fitness function will have 3 values:
#
# 1) Cost difference from target price
#
# 2) Time to eat
#
# 3) Amount of food
#
# -1 is trying to minimize value, 1 is trying to maximize value

# %%
creator.create('FitnessMulti', base.Fitness, weights=(1.0,-1.0,1.0))
creator.create('Individual', Counter, fitness = creator.FitnessMulti)

#Start with 3 items
IND_INIT_SIZE = 3

toolbox = base.Toolbox()
toolbox.register('attr_item', random.choice, ITEMS_NAME)
toolbox.register('individual', tools.initRepeat, creator.Individual, toolbox.attr_item, IND_INIT_SIZE)
toolbox.register('population', tools.initRepeat, list, toolbox.individual)

# %%
toolbox.population(n=5)
# Out:
# [Individual({'Hot Wings': 1, 'Side Salad': 1, 'French Fries': 1}),
#  Individual({'Side Salad': 1, 'Sampler Plate': 1, 'Mozzarella Sticks': 1}),
#  Individual({'Mixed Fruit': 1, 'Side Salad': 1, 'Mozzarella Sticks': 1}),
#  Individual({'Mozzarella Sticks': 1, 'Sampler Plate': 1, 'Hot Wings': 1}),
#  Individual({'French Fries': 1, 'Sampler Plate': 1, 'Hot Wings': 1})]

# %% [markdown]
# ## Evaluate Fitness and Return Error

# %%
def evalXKCD(individual, target_price):
    price = 0.0
    times = [0]
    food = 0
    for item, number in individual.items():
        if number > 0:
            price += ITEMS[item][0] * number
            times.append(ITEMS[item][1])
            food += number
    return (price - target_price), max(times), food

# %%
evalXKCD(creator.Individual({'French Fries' : 2, 'Hot Wings' : 0, 'Mixed Fruit' : 0, 
                            'Mozzarella Sticks' : 0, 'Sampler Plate' : 0, 'Side Salad' : 2}), 15.05)
# Out:
# (-2.8500000000000014, 5, 4)

# %% [markdown]
# ## Swap The Number of Randomly-chosen Items Between 2 Individuals

# %%
def cxCounter(ind1, ind2, indpb):
    for key in ITEMS.keys():
        if random.random() < indpb:
            ind1[key], ind2[key] = ind2[key], ind1[key]
    return ind1, ind2

# %%
cxCounter(creator.Individual({'French Fries' : 4, 'Hot Wings' : 0, 'Mixed Fruit' : 0, 
                            'Mozzarella Sticks' : 0, 'Sampler Plate' : 0, 'Side Salad' : 3}),
         creator.Individual({'French Fries' : 0, 'Hot Wings' : 1, 'Mixed Fruit' : 0, 
                            'Mozzarella Sticks' : 0, 'Sampler Plate' : 1, 'Side Salad' : 2}),
         0.5)
# Out:
# (Individual({'French Fries': 4,
#              'Hot Wings': 1,
#              'Mixed Fruit': 0,
#              'Mozzarella Sticks': 0,
#              'Sampler Plate': 1,
#              'Side Salad': 2}),
#  Individual({'French Fries': 0,
#              'Hot Wings': 0,
#              'Mixed Fruit': 0,
#              'Mozzarella Sticks': 0,
#              'Sampler Plate': 0,
#              'Side Salad': 3}))

# %% [markdown]
# ## Add or Remove items from an individual

# %%
def mutCounter(individual):
    if random.random() > 0.5:
        individual.update([random.choice(ITEMS_NAME)])
    else:
        val = random.choice(ITEMS_NAME)
        individual.subtract([val])
        if individual[val] < 0:
            del individual[val]
    return individual,

# %%
mutCounter(creator.Individual({'French Fries' : 4, 'Hot Wings' : 0, 'Mixed Fruit' : 0, 
                            'Mozzarella Sticks' : 0, 'Sampler Plate' : 0, 'Side Salad' : 3}))
# Out:
# (Individual({'French Fries': 4,
#              'Hot Wings': 0,
#              'Mixed Fruit': 0,
#              'Mozzarella Sticks': 0,
#              'Sampler Plate': 0,
#              'Side Salad': 4}),)

# %%
import sys

toolbox.register('evaluate', evalXKCD, target_price=15.05)

#Severely penalize targets over budget
toolbox.decorate('evaluate', tools.DeltaPenalty(lambda ind: evalXKCD(ind, 15.05)[0] <= 0,
                                               (-sys.float_info.max,
                                               sys.float_info.max,
                                               -sys.float_info.max)))

toolbox.register('mate', cxCounter, indpb = 0.5)
toolbox.register('mutate', mutCounter)
toolbox.register('select', tools.selNSGA2)

# %% [markdown]
# ## Simulation Parameters

# %%
# Number of generations = 100
NGEN = 100;
# Number of selected individuals
MU = 50;
# Number of children to produce
LAMBDA = 20;
# Probabilty offspring is produced by crossover
CXPB = 0.3;
# Probability offspring is produced by mutation
MUTPB = 0.3;

# Start population at 50
pop = toolbox.population(n=MU);

# %% [markdown]
# ## Keep Track of the 'Hall of Fame' Individual
#
# Hall of Fame contains the best individual that ever lived in the population during evolution

# %%
hof = tools.ParetoFront()

price_stats = tools.Statistics(key = lambda ind: ind.fitness.values[0])
time_stats = tools.Statistics(key = lambda ind: ind.fitness.values[1])
food_stats = tools.Statistics(key = lambda ind: ind.fitness.values[2])

stats = tools.MultiStatistics(price = price_stats, time = time_stats, food = food_stats)
stats.register('avg', numpy.mean, axis = 0)

algorithms.eaMuPlusLambda(pop, toolbox, MU, LAMBDA, CXPB, MUTPB, NGEN, stats, halloffame=hof)
# Out:
#    	      	         food         	        price         	         time
#    	      	----------------------	----------------------	----------------------
# gen	nevals	avg	gen	nevals	avg   	gen	nevals	avg 	gen	nevals
# 0  	50    	3  	0  	50    	-4.051	0  	50    	7.96	0  	50
# 1  	11    	3.04	1  	11    	-3.789	1  	11    	7.68	1  	11
# 2  	9     	3.14	2  	9     	-3.505	2  	9     	7.44	2  	9
# 3  	11    	3.14	3  	11    	-3.753	3  	11    	6.86	3  	11
# 4  	8     	3.26	4  	8     	-3.611	4  	8     	6.44	4  	8
# 5  	12    	3.3 	5  	12    	-4.117	5  	12    	5.68	5  	12
# 6  	12    	3.48	6  	12    	-3.565	6  	12    	5.84	6  	12
# 7  	10    	3.56	7  	10    	-3.41 	7  	10    	5.5 	7  	10
# 8  	13    	3.6 	8  	13    	-3.513	8  	13    	5.08	8  	13
# 9  	11    	3.6 	9  	11    	-3.397	9  	11    	4.86	9  	11
# 10 	12    	3.54	10 	12    	-3.969	10 	12    	4.32	10 	12
# 11 	15    	3.64	11 	15    	-3.546	11 	15    	4.4 	11 	15
# 12 	14    	3.8 	12 	14    	-3.292	12 	14    	4.36	12 	14
# 13 	16    	4   	13 	16    	-2.572	13 	16    	4.6 	13 	16
# 14 	11    	4.12	14 	11    	-2.698	14 	11    	4.62	14 	11
# 15 	14    	4.28	15 	14    	-2.024	15 	14    	4.92	15 	14
# 16 	11    	4.28	16 	11    	-1.642	16 	11    	5.16	16 	11
# 17 	10    	4.3 	17 	10    	-1.372	17 	10    	5.26	17 	10
# 18 	9     	4.22	18 	9     	-1.457	18 	9     	5.28	18 	9
# 19 	13    	4.28	19 	13    	-1.39 	19 	13    	5.68	19 	13
# 20 	16    	4.26	20 	16    	-1.323	20 	16    	5.92	20 	16
# 21 	11    	4.32	21 	11    	-1.728	21 	11    	5.54	21 	11
# 22 	12    	4.26	22 	12    	-2.023	22 	12    	5.52	22 	12
# 23 	13    	4.02	23 	13    	-2.505	23 	13    	5.68	23 	13
# 24 	14    	3.82	24 	14    	-2.975	24 	14    	5.38	24 	14
# 25 	10    	3.82	25 	10    	-3.307	25 	10    	5.18	25 	10
# 26 	8     	3.7 	26 	8     	-3.963	26 	8     	4.7 	26 	8
# 27 	10    	3.72	27 	10    	-4.81 	27 	10    	4.04	27 	10
# 28 	9     	3.66	28 	9     	-5.961	28 	9     	3.34	28 	9
# 29 	13    	3.82	29 	13    	-5.341	29 	13    	3.72	29 	13
# 30 	9     	4.06	30 	9     	-4.099	30 	9     	4.42	30 	9
# 31 	9     	4.26	31 	9     	-3.22 	31 	9     	4.92	31 	9
# 32 	17    	4.58	32 	17    	-2.505	32 	17    	4.92	32 	17
# 33 	12    	4.74	33 	12    	-2.225	33 	12    	5   	33 	12
# 34 	11    	4.9 	34 	11    	-1.115	34 	11    	6.12	34 	11
# 35 	9     	4.82	35 	9     	-1.503	35 	9     	5.8 	35 	9
# 36 	12    	4.92	36 	12    	-0.928	36 	12    	6.38	36 	12
# 37 	16    	4.92	37 	16    	-1.008	37 	16    	6.28	37 	16
# 38 	11    	4.92	38 	11    	-0.768	38 	11    	6.58	38 	11
# 39 	12    	4.92	39 	12    	-0.688	39 	12    	6.68	39 	12
# 40 	9     	4.92	40 	9     	-0.688	40 	9     	6.68	40 	9
# 41 	13    	4.94	41 	13    	-0.645	41 	13    	6.68	41 	13
# 42 	13    	4.94	42 	13    	-0.645	42 	13    	6.68	42 	13
# 43 	15    	4.94	43 	15    	-0.645	43 	15    	6.68	43 	15
# 44 	14    	4.86	44 	14    	-0.953	44 	14    	6.46	44 	14
# 45 	14    	4.86	45 	14    	-0.953	45 	14    	6.46	45 	14
# 46 	13    	4.88	46 	13    	-0.966	46 	13    	6.38	46 	13
# 47 	17    	4.88	47 	17    	-0.966	47 	17    	6.38	47 	17
# 48 	11    	5   	48 	11    	-0.3  	48 	11    	7   	48 	11
# 49 	11    	5   	49 	11    	-0.3  	49 	11    	7   	49 	11
# 50 	12    	5   	50 	12    	-0.3  	50 	12    	7   	50 	12
# 51 	14    	5   	51 	14    	-0.3  	51 	14    	7   	51 	14
# 52 	12    	5   	52 	12    	-0.3  	52 	12    	7   	52 	12
# 53 	12    	5   	53 	12    	-0.3  	53 	12    	7   	53 	12
# 54 	15    	5   	54 	15    	-0.3  	54 	15    	7   	54 	15
# 55 	14    	5   	55 	14    	-0.3  	55 	14    	7   	55 	14
# 56 	14    	5   	56 	14    	-0.3  	56 	14    	7   	56 	14
# 57 	16    	5   	57 	16    	-0.3  	57 	16    	7   	57 	16
# 58 	11    	5   	58 	11    	-0.3  	58 	11    	7   	58 	11
# 59 	12    	5   	59 	12    	-0.3  	59 	12    	7   	59 	12
# 60 	16    	5   	60 	16    	-0.3  	60 	16    	7   	60 	16
# 61 	13    	5   	61 	13    	-0.3  	61 	13    	7   	61 	13
# 62 	8     	5   	62 	8     	-0.3  	62 	8     	7   	62 	8
# 63 	12    	5   	63 	12    	-0.3  	63 	12    	7   	63 	12
# 64 	14    	5   	64 	14    	-0.3  	64 	14    	7   	64 	14
# 65 	9     	5   	65 	9     	-0.3  	65 	9     	7   	65 	9
# 66 	12    	5   	66 	12    	-0.3  	66 	12    	7   	66 	12
# 67 	9     	5   	67 	9     	-0.3  	67 	9     	7   	67 	9
# 68 	11    	5   	68 	11    	-0.3  	68 	11    	7   	68 	11
# 69 	14    	5   	69 	14    	-0.3  	69 	14    	7   	69 	14
# 70 	9     	5   	70 	9     	-0.3  	70 	9     	7   	70 	9
# 71 	12    	5   	71 	12    	-0.3  	71 	12    	7   	71 	12
# 72 	14    	5   	72 	14    	-0.3  	72 	14    	7   	72 	14
# 73 	12    	5   	73 	12    	-0.3  	73 	12    	7   	73 	12
# 74 	11    	5   	74 	11    	-0.3  	74 	11    	7   	74 	11
# 75 	17    	5   	75 	17    	-0.3  	75 	17    	7   	75 	17
# 76 	11    	5   	76 	11    	-0.3  	76 	11    	7   	76 	11
# 77 	11    	5   	77 	11    	-0.3  	77 	11    	7   	77 	11
# 78 	14    	5   	78 	14    	-0.3  	78 	14    	7   	78 	14
# 79 	14    	5   	79 	14    	-0.3  	79 	14    	7   	79 	14
# 80 	16    	5   	80 	16    	-0.3  	80 	16    	7   	80 	16
# 81 	14    	5   	81 	14    	-0.3  	81 	14    	7   	81 	14
# 82 	11    	5   	82 	11    	-0.3  	82 	11    	7   	82 	11
# 83 	16    	5   	83 	16    	-0.3  	83 	16    	7   	83 	16
# 84 	8     	5   	84 	8     	-0.3  	84 	8     	7   	84 	8
# 85 	12    	5   	85 	12    	-0.3  	85 	12    	7   	85 	12
# 86 	12    	5   	86 	12    	-0.3  	86 	12    	7   	86 	12
# 87 	12    	5   	87 	12    	-0.3  	87 	12    	7   	87 	12
# 88 	14    	5   	88 	14    	-0.3  	88 	14    	7   	88 	14
# 89 	16    	5   	89 	16    	-0.3  	89 	16    	7   	89 	16
# 90 	10    	5   	90 	10    	-0.3  	90 	10    	7   	90 	10
# 91 	13    	5   	91 	13    	-0.3  	91 	13    	7   	91 	13
# 92 	10    	5   	92 	10    	-0.3  	92 	10    	7   	92 	10
# 93 	10    	5   	93 	10    	-0.3  	93 	10    	7   	93 	10
# 94 	10    	5   	94 	10    	-0.3  	94 	10    	7   	94 	10
# 95 	10    	5   	95 	10    	-0.3  	95 	10    	7   	95 	10
# 96 	15    	5   	96 	15    	-0.3  	96 	15    	7   	96 	15
# 97 	9     	5   	97 	9     	-0.3  	97 	9     	7   	97 	9
# 98 	11    	5   	98 	11    	-0.3  	98 	11    	7   	98 	11
# 99 	12    	5   	99 	12    	-0.3  	99 	12    	7   	99 	12
# 100	14    	5   	100	14    	-0.3  	100	14    	7   	100	14
# ([Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0}),
#   Individual({'Side Salad': 1,
#               'Hot Wings': 2,
#               'Mozzarella Sticks': 0,
#               'Mixed Fruit': 2,
#               'Sampler Plate': 0})],
#  [{'gen': 0, 'nevals': 50},
#   {'gen': 1, 'nevals': 11},
#   {'gen': 2, 'nevals': 9},
#   {'gen': 3, 'nevals': 11},
#   {'gen': 4, 'nevals': 8},
#   {'gen': 5, 'nevals': 12},
#   {'gen': 6, 'nevals': 12},
#   {'gen': 7, 'nevals': 10},
#   {'gen': 8, 'nevals': 13},
#   {'gen': 9, 'nevals': 11},
#   {'gen': 10, 'nevals': 12},
#   {'gen': 11, 'nevals': 15},
#   {'gen': 12, 'nevals': 14},
#   {'gen': 13, 'nevals': 16},
#   {'gen': 14, 'nevals': 11},
#   {'gen': 15, 'nevals': 14},
#   {'gen': 16, 'nevals': 11},
#   {'gen': 17, 'nevals': 10},
#   {'gen': 18, 'nevals': 9},
#   {'gen': 19, 'nevals': 13},
#   {'gen': 20, 'nevals': 16},
#   {'gen': 21, 'nevals': 11},
#   {'gen': 22, 'nevals': 12},
#   {'gen': 23, 'nevals': 13},
#   {'gen': 24, 'nevals': 14},
#   {'gen': 25, 'nevals': 10},
#   {'gen': 26, 'nevals': 8},
#   {'gen': 27, 'nevals': 10},
#   {'gen': 28, 'nevals': 9},
#   {'gen': 29, 'nevals': 13},
#   {'gen': 30, 'nevals': 9},
#   {'gen': 31, 'nevals': 9},
#   {'gen': 32, 'nevals': 17},
#   {'gen': 33, 'nevals': 12},
#   {'gen': 34, 'nevals': 11},
#   {'gen': 35, 'nevals': 9},
#   {'gen': 36, 'nevals': 12},
#   {'gen': 37, 'nevals': 16},
#   {'gen': 38, 'nevals': 11},
#   {'gen': 39, 'nevals': 12},
#   {'gen': 40, 'nevals': 9},
#   {'gen': 41, 'nevals': 13},
#   {'gen': 42, 'nevals': 13},
#   {'gen': 43, 'nevals': 15},
#   {'gen': 44, 'nevals': 14},
#   {'gen': 45, 'nevals': 14},
#   {'gen': 46, 'nevals': 13},
#   {'gen': 47, 'nevals': 17},
#   {'gen': 48, 'nevals': 11},
#   {'gen': 49, 'nevals': 11},
#   {'gen': 50, 'nevals': 12},
#   {'gen': 51, 'nevals': 14},
#   {'gen': 52, 'nevals': 12},
#   {'gen': 53, 'nevals': 12},
#   {'gen': 54, 'nevals': 15},
#   {'gen': 55, 'nevals': 14},
#   {'gen': 56, 'nevals': 14},
#   {'gen': 57, 'nevals': 16},
#   {'gen': 58, 'nevals': 11},
#   {'gen': 59, 'nevals': 12},
#   {'gen': 60, 'nevals': 16},
#   {'gen': 61, 'nevals': 13},
#   {'gen': 62, 'nevals': 8},
#   {'gen': 63, 'nevals': 12},
#   {'gen': 64, 'nevals': 14},
#   {'gen': 65, 'nevals': 9},
#   {'gen': 66, 'nevals': 12},
#   {'gen': 67, 'nevals': 9},
#   {'gen': 68, 'nevals': 11},
#   {'gen': 69, 'nevals': 14},
#   {'gen': 70, 'nevals': 9},
#   {'gen': 71, 'nevals': 12},
#   {'gen': 72, 'nevals': 14},
#   {'gen': 73, 'nevals': 12},
#   {'gen': 74, 'nevals': 11},
#   {'gen': 75, 'nevals': 17},
#   {'gen': 76, 'nevals': 11},
#   {'gen': 77, 'nevals': 11},
#   {'gen': 78, 'nevals': 14},
#   {'gen': 79, 'nevals': 14},
#   {'gen': 80, 'nevals': 16},
#   {'gen': 81, 'nevals': 14},
#   {'gen': 82, 'nevals': 11},
#   {'gen': 83, 'nevals': 16},
#   {'gen': 84, 'nevals': 8},
#   {'gen': 85, 'nevals': 12},
#   {'gen': 86, 'nevals': 12},
#   {'gen': 87, 'nevals': 12},
#   {'gen': 88, 'nevals': 14},
#   {'gen': 89, 'nevals': 16},
#   {'gen': 90, 'nevals': 10},
#   {'gen': 91, 'nevals': 13},
#   {'gen': 92, 'nevals': 10},
#   {'gen': 93, 'nevals': 10},
#   {'gen': 94, 'nevals': 10},
#   {'gen': 95, 'nevals': 10},
#   {'gen': 96, 'nevals': 15},
#   {'gen': 97, 'nevals': 9},
#   {'gen': 98, 'nevals': 11},
#   {'gen': 99, 'nevals': 12},
#   {'gen': 100, 'nevals': 14}])

# %%
print('Best:', hof[0], hof[0].fitness.values)
# Out:
# Best: Individual({'Hot Wings': 2, 'Mixed Fruit': 2, 'Side Salad': 1, 'Mozzarella Sticks': 0, 'French Fries': 0}) (-0.3000000000000007, 7.0, 5.0)
