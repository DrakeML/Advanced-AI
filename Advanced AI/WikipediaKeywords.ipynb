# %%
import wikipedia

# %%
ny = wikipedia.page('New York City')

# %%
ny.content[:1000]
# Out:
# "The City of New York, usually called either New York City (NYC) or simply New York (NY), is the most populous city in the United States. With an estimated 2018 population of 8,398,748 distributed over a land area of about 302.6 square miles (784 km2), New York is also the most densely populated major city in the United States. Located at the southern tip of the state of New York, the city is the center of the New York metropolitan area, the largest metropolitan area in the world by urban landmass and one of the world's most populous megacities, with an estimated 19,979,477 people in its 2018 Metropolitan Statistical Area and 22,679,948 residents in its Combined Statistical Area. A global power city, New York City has been described as the cultural, financial, and media capital of the world, and exerts a significant impact upon commerce, entertainment, research, technology, education, politics, tourism, art, fashion, and sports. The city's fast pace has inspired the term New York minute"

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
nynlp = nlp(ny.content[:10000])

# %%
for chunk in nynlp.noun_chunks:
    print(chunk.text, '/', chunk.root.text, '/', chunk.root.dep_, '/', chunk.root.head.text)
# Out:
# The City / City / nsubj / called
# New York / York / pobj / of
# New York City / City / pobj / either
# NYC / NYC / appos / City
# simply New York / York / conj / City
# NY / NY / appos / York
# the most populous city / city / attr / is
# the United States / States / pobj / in
# an estimated 2018 population / population / pobj / With
# a land area / area / pobj / over
# about 302.6 square miles / miles / pobj / of
# 784 km2 / km2 / appos / miles
# New York / York / nsubj / is
# the most densely populated major city / city / attr / is
# the United States / States / pobj / in
# the southern tip / tip / pobj / at
# the state / state / pobj / of
# New York / York / pobj / of
# the city / city / nsubj / is
# the center / center / attr / is
# the New York metropolitan area / area / pobj / of
# the largest metropolitan area / area / appos / center
# the world / world / pobj / in
# urban landmass / landmass / pobj / by
# the world's most populous megacities / megacities / pobj / of
# an estimated 19,979,477 people / people / pobj / with
# its 2018 Metropolitan Statistical Area / Area / pobj / in
# 22,679,948 residents / residents / conj / people
# its Combined Statistical Area / Area / pobj / in
# A global power city / city / nsubjpass / described
# New York City / City / appos / city
# the cultural, financial, and media capital / capital / pobj / as
# the world / world / pobj / of
# a significant impact / impact / dobj / exerts
# commerce / commerce / pobj / upon
# entertainment / entertainment / conj / commerce
# research / research / conj / entertainment
# technology / technology / conj / research
# education / education / conj / technology
# politics / politics / conj / education
# tourism / tourism / conj / politics
# art / art / conj / tourism
# fashion / fashion / conj / art
# sports / sports / conj / fashion
# The city's fast pace / pace / nsubj / inspired
# the term / term / dobj / inspired
# New York minute / minute / appos / term
# the headquarters / headquarters / pobj / to
# the United Nations / Nations / pobj / of
# New York / York / nsubj / is
# an important center / center / attr / is
# international diplomacy / diplomacy / pobj / for
# the world's largest natural harbors / harbors / pobj / of
# New York City / City / nsubj / consists
# five boroughs / boroughs / pobj / of
# a separate county / county / attr / is
# the State / State / pobj / of
# New York / York / pobj / of
# The five boroughs – Brooklyn / Brooklyn / nsubjpass / consolidated
# Queens / Queens / conj / Brooklyn
# Manhattan / Manhattan / conj / Queens
# The Bronx / Bronx / conj / Manhattan
# a single city / city / pobj / into
# The city / city / nsubj / constitute
# its metropolitan area / area / conj / city
# the premier gateway / gateway / dobj / constitute
# legal immigration / immigration / pobj / for
# the United States / States / pobj / to
# As many as 800 languages / languages / nsubjpass / spoken
# New York / York / pobj / in
# it / it / nsubj / city
# the world / world / pobj / in
# New York City / City / nsubj / is
# home / home / attr / is
# more than 3.2 million residents / residents / pobj / to
# the United States / States / pobj / outside
# the largest foreign-born population / population / appos / States
# any city / city / pobj / of
# the world / world / pobj / in
# the New York metropolitan area / area / nsubjpass / estimated
# a gross metropolitan product / product / dobj / produce
# GMP / GMP / appos / product
# greater New York City / City / nsubj / were
# a sovereign state / state / attr / were
# it / it / nsubj / have
# the 12th highest GDP / GDP / dobj / have
# the world / world / pobj / in
# New York / York / nsubj / is
# home / home / attr / is
# the highest number / number / pobj / to
# billionaires / billionaires / pobj / of
# any city / city / pobj / of
# the world / world / pobj / in
# New York City / City / nsubj / traces
# its origins / origins / dobj / traces
# a trading post / post / pobj / to
# colonists / colonists / pobj / by
# the Dutch Republic / Republic / pobj / from
# Lower Manhattan / Manhattan / pobj / on
# the post / post / nsubjpass / named
# The city / city / nsubj / came
# its surroundings / surroundings / conj / city
# English control / control / pobj / under
# King Charles II / II / nsubj / granted
# England / England / pobj / of
# the lands / lands / dobj / granted
# his brother / brother / pobj / to
# the Duke / Duke / appos / brother
# York / York / pobj / of
# New York / York / nsubj / served
# the capital / capital / pobj / as
# the United States / States / pobj / of
# It / It / nsubj / been
# the country's largest city / city / attr / been
# The Statue / Statue / nsubj / greeted
# Liberty / Liberty / pobj / of
# millions / millions / dobj / greeted
# immigrants / immigrants / pobj / of
# they / they / nsubj / came
# the U.S. / U.S. / pobj / to
# ship / ship / pobj / by
# the late 19th and early 20th centuries / centuries / pobj / in
# an international symbol / symbol / attr / is
# the U.S. / U.S. / pobj / of
# its ideals / ideals / conj / U.S.
# liberty / liberty / pobj / of
# peace / peace / conj / liberty
# the 21st century / century / pobj / In
# New York / York / nsubj / emerged
# a global node / node / pobj / as
# creativity / creativity / pobj / of
# entrepreneurship / entrepreneurship / conj / creativity
# social tolerance / tolerance / conj / creativity
# environmental sustainability / sustainability / conj / tolerance
# a symbol / symbol / pobj / as
# freedom / freedom / pobj / of
# cultural diversity / diversity / conj / freedom
# New York / York / nsubjpass / voted
# the greatest city / city / dobj / voted
# the world / world / pobj / in
# a survey / survey / pobj / per
# over 30,000 people / people / pobj / of
# 48 cities / cities / pobj / from
# the city's cultural diversity / diversity / dobj / citing
# Many districts / districts / nsubj / are
# landmarks / landmarks / conj / districts
# New York City / City / pobj / in
# the city / city / nsubj / having
# the world's ten most visited tourist attractions / attractions / pobj / of
# a record 62.8 million tourists / tourists / dobj / receiving
# Several sources / sources / nsubj / ranked
# New York / York / dobj / ranked
# the most photographed city / city / dobj / ranked
# the world / world / pobj / in
# Times Square / Square / nsubj / is
# the world's "heart / heart / pobj / as
# its "Crossroads / Crossroads / conj / heart
# the brightly illuminated hub / hub / attr / is
# the Broadway Theater District / District / pobj / of
# the world's busiest pedestrian intersections / intersections / pobj / of
# a major center / center / conj / one
# the world's entertainment industry / industry / pobj / of
# The names / names / nsubjpass / known
# the city's landmarks / landmarks / pobj / of
# skyscrapers / skyscrapers / conj / landmarks
# parks / parks / conj / skyscrapers
# the world / world / pobj / around
# Manhattan's real estate market / market / nsubj / is
# the world / world / pobj / in
# New York / York / nsubj / is
# home / home / attr / is
# the largest ethnic Chinese population / population / pobj / to
# Asia / Asia / pobj / of
# multiple signature / signature / nsubj / developing
# Chinatowns / Chinatowns / nsubj / developing
# the city / city / pobj / across
# continuous 24/7 service / service / dobj / Providing
# the New York City Subway / Subway / nsubj / is
# the largest single-operator rapid transit system / system / attr / is
# 472 rail stations / stations / pobj / with
# Over 120 colleges / colleges / nsubjpass / located
# universities / universities / conj / colleges
# New York City / City / pobj / in
# Columbia University / University / pobj / including
# New York University / University / conj / University
# Rockefeller University / University / conj / University
# the top universities / universities / pobj / among
# the world / world / pobj / in
# Wall Street / Street / pobj / by
# the Financial District / District / pobj / in
# Lower Manhattan / Manhattan / pobj / of
# New York / York / nsubjpass / called
# the world / world / pobj / of
# the city / city / nsubj / is
# home / home / attr / is
# the world's two largest stock exchanges / exchanges / pobj / to
# total market capitalization / capitalization / pobj / by
# the New York Stock Exchange / Exchange / conj / is
# NASDAQ / NASDAQ / conj / Exchange
# History / History / ROOT / History
# Etymology / Etymology / ROOT / Etymology
# the city / city / nsubjpass / named
# honor / honor / pobj / in
# the Duke / Duke / pobj / of
# York / York / pobj / of
# who / who / nsubj / become
# King James II / II / attr / become
# England / England / pobj / of
# James's older brother / brother / nsubj / appointed
# King Charles II / II / appos / brother
# the Duke proprietor / proprietor / dobj / appointed
# the former territory / territory / pobj / of
# New Netherland / Netherland/ of
# England / England / nsubj / seized
# the Dutch / Dutch / pobj
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
for ent in nynlp.ents:
    print(ent.text, '/', ent.start_char, '/', ent.end_char, '/', ent.label_)
# Out:
# The City of New York / 0 / 20 / GPE
# New York City ( / 44 / 59 / GPE
# New York / 74 / 82 / GPE
# the United States / 118 / 135 / GPE
# 2018 / 155 / 159 / DATE
# 8,398,748 / 174 / 183 / CARDINAL
# about 302.6 square miles / 216 / 240 / QUANTITY
# 784 / 242 / 245 / CARDINAL
# New York / 252 / 260 / GPE
# the United States / 310 / 327 / GPE
# New York / 373 / 381 / GPE
# New York / 413 / 421 / GPE
# one / 506 / 509 / CARDINAL
# an estimated 19,979,477 / 556 / 579 / CARDINAL
# 2018 / 594 / 598 / DATE
# Metropolitan Statistical Area / 599 / 628 / ORG
# 22,679,948 / 633 / 643 / CARDINAL
# Combined Statistical Area / 661 / 686 / LOC
# New York City / 709 / 722 / GPE
# New York / 985 / 993 / GPE
# the United Nations / 1030 / 1048 / ORG
# New York / 1050 / 1058 / GPE
# one / 1122 / 1125 / CARDINAL
# New York City / 1166 / 1179 / GPE
# five / 1192 / 1196 / CARDINAL
# the State of New York / 1245 / 1266 / GPE
# five / 1272 / 1276 / CARDINAL
# Brooklyn / 1288 / 1296 / GPE
# Queens / 1298 / 1304 / GPE
# Manhattan / 1306 / 1315 / GPE
# Bronx / 1321 / 1326 / GPE
# Staten Island / 1332 / 1345 / LOC
# 1898 / 1388 / 1392 / DATE
# the United States / 1485 / 1502 / GPE
# As many as 800 / 1504 / 1518 / CARDINAL
# New York / 1543 / 1551 / GPE
# New York City / 1614 / 1627 / GPE
# more than 3.2 million / 1639 / 1660 / CARDINAL
# the United States / 1684 / 1701 / GPE
# 2019 / 1771 / 1775 / DATE
# New York / 1781 / 1789 / GPE
# GMP / 1862 / 1865 / ORG
# US$1.9 trillion / 1870 / 1885 / MONEY
# New York City / 1898 / 1911 / GPE
# 12th / 1954 / 1958 / ORDINAL
# New York / 1985 / 1993 / GPE
# New York City / 2065 / 2078 / GPE
# the Dutch Republic / 2142 / 2160 / GPE
# 1624 / 2164 / 2168 / DATE
# Lower Manhattan / 2172 / 2187 / LOC
# New Amsterdam / 2208 / 2221 / GPE
# 1626 / 2225 / 2229 / DATE
# English / 2272 / 2279 / LANGUAGE
# 1664 / 2291 / 2295 / DATE
# New York / 2313 / 2321 / GPE
# Charles II / 2333 / 2343 / PERSON
# England / 2347 / 2354 / GPE
# New York / 2407 / 2415 / GPE
# the United States / 2441 / 2458 / GPE
# 1785 / 2464 / 2468 / DATE
# 1790 / 2475 / 2479 / DATE
# 1790 / 2526 / 2530 / DATE
# The Statue of Liberty / 2532 / 2553 / FAC
# millions / 2562 / 2570 / CARDINAL
# U.S. / 2605 / 2609 / GPE
# the late 19th / 2621 / 2634 / DATE
# early 20th centuries / 2639 / 2659 / DATE
# U.S. / 2698 / 2702 / GPE
# the 21st century / 2743 / 2759 / DATE
# New York / 2761 / 2769 / GPE
# 2019 / 2941 / 2945 / DATE
# New York / 2947 / 2955 / GPE
# over 30,000 / 3013 / 3024 / CARDINAL
# 48 / 3037 / 3039 / CARDINAL
# New York City / 3127 / 3140 / GPE
# three / 3178 / 3183 / CARDINAL
# ten / 3199 / 3202 / CARDINAL
# 2013 / 3239 / 3243 / DATE
# 62.8 million / 3267 / 3279 / CARDINAL
# 2017 / 3292 / 3296 / DATE
# New York / 3326 / 3334 / GPE
# Times Square / 3376 / 3388 / FAC
# Crossroads / 3429 / 3439 / WORK_OF_ART
# the Broadway Theater District / 3477 / 3506 / ORG
# one / 3508 / 3511 / CARDINAL
# Manhattan / 3713 / 3722 / GPE
# New York / 3786 / 3794 / GPE
# Chinese / 3825 / 3832 / NORP
# Asia / 3855 / 3859 / LOC
# Chinatowns / 3885 / 3895 / PERSON
# 472 / 4052 / 4055 / CARDINAL
# 120 / 4076 / 4079 / CARDINAL
# New York City / 4121 / 4134 / GPE
# Columbia University / 4146 / 4165 / ORG
# New York University / 4167 / 4186 / ORG
# Rockefeller University / 4192 / 4214 / ORG
# the Financial District of Lower Manhattan / 4308 / 4349 / LOC
# New York / 4351 / 4359 / GPE
# two / 4500 / 4503 / CARDINAL
# the New York Stock Exchange / 4560 / 4587 / ORG
# NASDAQ / 4592 / 4598 / ORG
# 1664 / 4639 / 4643 / DATE
# James II / 4716 / 4724 / PERSON
# England / 4728 / 4735 / GPE
# James / 4737 / 4742 / PERSON
# Charles II / 4765 / 4775 / PERSON
# Duke / 4795 / 4799 / ORG
# New Netherland / 4838 / 4852 / ORG
# New Amsterdam / 4876 / 4889 / GPE
# England / 4897 / 4904 / GPE
# Dutch / 4934 / 4939 / NORP
# Wisconsin / 4976 / 4985 / GPE
# 75,000 to 11,000 years ago / 4998 / 5024 / DATE
# New York City / 5030 / 5043 / GPE
# 2,000 feet / 5102 / 5112 / QUANTITY
# 610 / 5114 / 5117 / CARDINAL
# Long Island / 5245 / 5256 / GPE
# Staten Island / 5261 / 5274 / LOC
# Manhattan / 5378 / 5387 / GPE
# present-day / 5438 / 5449 / DATE
# New York City / 5450 / 5463 / GPE
# Algonquian Native Americans / 5481 / 5508 / NORP
# Lenape / 5524 / 5530 / NORP
# Lenapehoking / 5557 / 5569 / ORG
# Staten Island / 5580 / 5593 / LOC
# Long Island / 5618 / 5629 / GPE
# Brooklyn / 5668 / 5676 / GPE
# Queens / 5681 / 5687 / GPE
# Manhattan / 5689 / 5698 / GPE
# Bronx / 5704 / 5709 / GPE
# the Lower Hudson Valley / 5715 / 5738 / LOC
# first / 5743 / 5748 / ORDINAL
# New York Harbor / 5771 / 5786 / LOC
# European / 5792 / 5800 / NORP
# 1524 / 5808 / 5812 / DATE
# Giovanni da Verrazzano / 5816 / 5838 / ORG
# Florentine / 5842 / 5852 / PERSON
# French / 5884 / 5890 / NORP
# France / 5922 / 5928 / GPE
# Nouvelle Angoulême / 5942 / 5960 / PERSON
# Spanish / 5980 / 5987 / NORP
# Estêvão Gomes / 6014 / 6027 / PERSON
# Portuguese / 6031 / 6041 / NORP
# Charles V / 6062 / 6071 / PERSON
# New York Harbor / 6084 / 6099 / LOC
# January 1525 / 6103 / 6115 / DATE
# the Hudson River / 6141 / 6157 / LOC
# Río de San Antonio / 6174 / 6192 / FAC
# Saint Anthony's River / 6194 / 6215 / FAC
# The Padrón Real of 1527 / 6218 / 6241 / WORK_OF_ART
# first / 6247 / 6252 / ORDINAL
# the East Coast / 6276 / 6290 / LOC
# North America / 6294 / 6307 / LOC
# Gomes / 6338 / 6343 / PERSON
# United States / 6385 / 6398 / GPE
# Tierra de Esteban Gómez / 6402 / 6425 / ORG
# 1609 / 6444 / 6448 / DATE
# English / 6454 / 6461 / NORP
# Henry Hudson / 6471 / 6483 / PERSON
# the Northwest Passage / 6537 / 6558 / ORG
# Orient / 6566 / 6572 / LOC
# East India Company / 6587 / 6605 / ORG
# Dutch / 6640 / 6645 / NORP
# the North River / 6657 / 6672 / LOC
# the Hudson River / 6678 / 6694 / LOC
# Hudson / 6712 / 6718 / PERSON
# Mauritius / 6726 / 6735 / ORG
# Maurice / 6742 / 6749 / ORG
# Hudson / 6769 / 6775 / PERSON
# first / 6778 / 6783 / ORDINAL
# Harbour / 6826 / 6833 / PERSON
# Hudson / 6902 / 6908 / PERSON
# roughly 150 miles / 6916 / 6933 / QUANTITY
# 240 km / 6935 / 6941 / QUANTITY
# New York State / 6984 / 6998 / GPE
# Albany / 7015 / 7021 / GPE
# ten-day / 7134 / 7141 / DATE
# the Dutch East India Company / 7193 / 7221 / ORG
# 1614 / 7226 / 7230 / DATE
# Cape Cod / 7249 / 7257 / PERSON
# Delaware Bay / 7262 / 7274 / LOC
# Netherlands / 7294 / 7305 / GPE
# Nieuw-Nederland / 7317 / 7332 / ORG
# New York City / 7424 / 7437 / GPE
# Juan Rodriguez / 7442 / 7456 / PERSON
# Dutch / 7476 / 7481 / NORP
# Jan Rodrigues / 7485 / 7498 / PERSON
# Santo Domingo / 7517 / 7530 / PERSON
# Santo Domingo of Portuguese and African descent, he arrived in / 7540 / 7602 / WORK_OF_ART
# Manhattan / 7603 / 7612 / GPE
# the winter / 7620 / 7630 / DATE
# Dutch / 7727 / 7732 / NORP
# Broadway / 7734 / 7742 / FAC
# 159th Street / 7749 / 7761 / FAC
# 218th Street / 7765 / 7777 / FAC
# Upper Manhattan / 7781 / 7796 / GPE
# Juan Rodriguez Way / 7807 / 7825 / PERSON
# Dutch / 7846 / 7851 / NORP
# European / 7874 / 7882 / NORP
# New Netherland / 7895 / 7909 / ORG
# 1624 / 7919 / 7923 / DATE
# New York / 7933 / 7941 / GPE
# the 12th / 7942 / 7950 / DATE
# European / 7980 / 7988 / NORP
# United States / 8031 / 8044 / GPE
# Dutch / 8070 / 8075 / NORP
# Governors Island / 8102 / 8118 / LOC
# 1625 / 8123 / 8127 / DATE
# Fort Amsterdam / 8171 / 8185 / GPE
# Nieuw Amsterdam / 8200 / 8215 / LOC
# New Amsterdam / 8217 / 8230 / GPE
# present-day / 8236 / 8247 / DATE
# Manhattan Island / 8248 / 8264 / GPE
# New Amsterdam / 8280 / 8293 / GPE
# Lower Manhattan /
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
for token in nlp(u'The Statue of Liberty greeted millions of immigrants who came to the Americas by ship in the late 19th and early 20th centuries and is a world symbol of the United States and its ideals of liberty and peace.'):
    print(token.text, '/', token.pos_, '/', token.tag_, '/', token.is_alpha, '/', token.is_stop)
# Out:
# The / DET / DT / True / True
# Statue / PROPN / NNP / True / False
# of / ADP / IN / True / True
# Liberty / PROPN / NNP / True / False
# greeted / VERB / VBD / True / False
# millions / NOUN / NNS / True / False
# of / ADP / IN / True / True
# immigrants / NOUN / NNS / True / False
# who / PRON / WP / True / True
# came / VERB / VBD / True / False
# to / ADP / IN / True / True
# the / DET / DT / True / True
# Americas / PROPN / NNPS / True / False
# by / ADP / IN / True / True
# ship / NOUN / NN / True / False
# in / ADP / IN / True / True
# the / DET / DT / True / True
# late / ADJ / JJ / True / False
# 19th / NOUN / NN / False / False
# and / CCONJ / CC / True / True
# early / ADJ / JJ / True / False
# 20th / ADJ / JJ / False / False
# centuries / NOUN / NNS / True / False
# and / CCONJ / CC / True / True
# is / VERB / VBZ / True / True
# a / DET / DT / True / True
# world / NOUN / NN / True / False
# symbol / NOUN / NN / True / False
# of / ADP / IN / True / True
# the / DET / DT / True / True
# United / PROPN / NNP / True / False
# States / PROPN / NNP / True / False
# and / CCONJ / CC / True / True
# its / DET / PRP$ / True / True
# ideals / NOUN / NNS / True / False
# of / ADP / IN / True / True
# liberty / NOUN / NN / True / False
# and / CCONJ / CC / True / True
# peace / NOUN / NN / True / False
# . / PUNCT / . / False / False

# %%
from spacy.matcher import Matcher

# %%
from spacy import displacy

# %%
matcher = Matcher(nlp.vocab)
matched_sents = [] #collected data of matched sentences
matched_phrases = [] #matched phrases without sentences

def collect_sents(matcher, doc, i, matches):
    match_id, start, end = matches[i]
    span = doc[start : end] #matched span
    sent = span.sent #sentence containing matched span
    
    #append mock entity for match in displaCy style to matched_sents
    #get match span by offsetting start and end end of span
    
    match_ents = [{'start' : span.start_char - sent.start_char,
                  'end' : span.end_char - sent.end_char,
                  'label' : 'MATCH'}]
    matched_sents.append({'text' : sent.text, 'ents' : match_ents})
    matched_phrases.append(span.text)

# %%
pattern = [{'POS' : 'NOUN'}, {'POS' : 'NOUN'}]

# %%
matcher.add('nounphrase', collect_sents, pattern)

# %%
matches = matcher(nynlp)

# %%
matches
# Out:
# [(8429085606845659861, 43, 45),
#  (8429085606845659861, 136, 138),
#  (8429085606845659861, 152, 154),
#  (8429085606845659861, 284, 286),
#  (8429085606845659861, 417, 419),
#  (8429085606845659861, 632, 634),
#  (8429085606845659861, 694, 696),
#  (8429085606845659861, 705, 707),
#  (8429085606845659861, 731, 733),
#  (8429085606845659861, 758, 760),
#  (8429085606845659861, 782, 784),
#  (8429085606845659861, 788, 790),
#  (8429085606845659861, 871, 873),
#  (8429085606845659861, 875, 877),
#  (8429085606845659861, 997, 999),
#  (8429085606845659861, 1377, 1379),
#  (8429085606845659861, 1406, 1408),
#  (8429085606845659861, 1584, 1586),
#  (8429085606845659861, 1585, 1587),
#  (8429085606845659861, 1723, 1725),
#  (8429085606845659861, 1734, 1736),
#  (8429085606845659861, 1754, 1756),
#  (8429085606845659861, 1794, 1796),
#  (8429085606845659861, 1850, 1852),
#  (8429085606845659861, 1938, 1940)]

# %%
matched_sents
# Out:
# [{'text': 'With an estimated 2018 population of 8,398,748 distributed over a land area of about 302.6 square miles (784 km2), New York is also the most densely populated major city in the United States.',
#   'ents': [{'start': 66, 'end': -116, 'label': 'MATCH'}]},
#  {'text': 'A global power city, New York City has been described as the cultural, financial, and media capital of the world, and exerts a significant impact upon commerce, entertainment, research, technology, education, politics, tourism, art, fashion, and sports.',
#   'ents': [{'start': 9, 'end': -234, 'label': 'MATCH'}]},
#  {'text': 'A global power city, New York City has been described as the cultural, financial, and media capital of the world, and exerts a significant impact upon commerce, entertainment, research, technology, education, politics, tourism, art, fashion, and sports.',
#   'ents': [{'start': 86, 'end': -154, 'label': 'MATCH'}]},
#  {'text': 'The city and its metropolitan area constitute the premier gateway for legal immigration to the United States.',
#   'ents': [{'start': 50, 'end': -44, 'label': 'MATCH'}]},
#  {'text': 'New York City traces its origins to a trading post founded by colonists from the Dutch Republic in 1624 on Lower Manhattan; the post was named New Amsterdam in 1626.',
#   'ents': [{'start': 38, 'end': -115, 'label': 'MATCH'}]},
#  {'text': "Many districts and landmarks in New York City are well known, with the city having three of the world's ten most visited tourist attractions in 2013 and receiving a record 62.8 million tourists in 2017.",
#   'ents': [{'start': 121, 'end': -62, 'label': 'MATCH'}]},
#  {'text': 'Times Square, iconic as the world\'s "heart" and its "Crossroads", is the brightly illuminated hub of the Broadway Theater District, one of the world\'s busiest pedestrian intersections, and a major center of the world\'s entertainment industry.',
#   'ents': [{'start': 159, 'end': -59, 'label': 'MATCH'}]},
#  {'text': 'Times Square, iconic as the world\'s "heart" and its "Crossroads", is the brightly illuminated hub of the Broadway Theater District, one of the world\'s busiest pedestrian intersections, and a major center of the world\'s entertainment industry.',
#   'ents': [{'start': 219, 'end': -1, 'label': 'MATCH'}]},
#  {'text': "Manhattan's real estate market is among the most expensive in the world.",
#   'ents': [{'start': 17, 'end': -42, 'label': 'MATCH'}]},
#  {'text': 'New York is home to the largest ethnic Chinese population outside of Asia, with multiple signature Chinatowns developing across the city.',
#   'ents': [{'start': 89, 'end': -28, 'label': 'MATCH'}]},
#  {'text': 'Providing continuous 24/7 service, the New York City Subway is the largest single-operator rapid transit system worldwide, with 472 rail stations.',
#   'ents': [{'start': 97, 'end': -35, 'label': 'MATCH'}]},
#  {'text': 'Providing continuous 24/7 service, the New York City Subway is the largest single-operator rapid transit system worldwide, with 472 rail stations.',
#   'ents': [{'start': 132, 'end': -1, 'label': 'MATCH'}]},
#  {'text': "Anchored by Wall Street in the Financial District of Lower Manhattan, New York has been called both the most economically powerful city and the leading financial center of the world, and the city is home to the world's two largest stock exchanges by total market capitalization, the New York Stock Exchange and NASDAQ.\n\n\n",
#   'ents': [{'start': 231, 'end': -75, 'label': 'MATCH'}]},
#  {'text': "Anchored by Wall Street in the Financial District of Lower Manhattan, New York has been called both the most economically powerful city and the leading financial center of the world, and the city is home to the world's two largest stock exchanges by total market capitalization, the New York Stock Exchange and NASDAQ.\n\n\n",
#   'ents': [{'start': 256, 'end': -44, 'label': 'MATCH'}]},
#  {'text': '===\nDuring the Wisconsin glaciation, 75,000 to 11,000 years ago, the New York City region was situated at the edge of a large ice sheet over 2,000 feet (610 m) in depth.',
#   'ents': [{'start': 126, 'end': -34, 'label': 'MATCH'}]},
#  {'text': 'Hudson sailed roughly 150 miles (240 km) north, past the site of the  present-day New York State capital city of Albany, in the belief that it might be an oceanic tributary before the river became too shallow to continue.',
#   'ents': [{'start': 97, 'end': -112, 'label': 'MATCH'}]},
#  {'text': 'He made a ten-day exploration of the area and claimed the region for the Dutch East India Company.',
#   'ents': [{'start': 14, 'end': -69, 'label': 'MATCH'}]},
#  {'text': 'A permanent European presence in New Netherland began in 1624 – making New York the 12th oldest continuously occupied European-established settlement in the continental United States – with the founding of a Dutch fur trading settlement on Governors Island.',
#   'ents': [{'start': 214, 'end': -32, 'label': 'MATCH'}]},
#  {'text': 'A permanent European presence in New Netherland began in 1624 – making New York the 12th oldest continuously occupied European-established settlement in the continental United States – with the founding of a Dutch fur trading settlement on Governors Island.',
#   'ents': [{'start': 218, 'end': -21, 'label': 'MATCH'}]},
#  {'text': 'A disproved legend claims that Manhattan was purchased for $24 worth of glass beads.',
#   'ents': [{'start': 12, 'end': -59, 'label': 'MATCH'}]},
#  {'text': 'A disproved legend claims that Manhattan was purchased for $24 worth of glass beads.',
#   'ents': [{'start': 72, 'end': -1, 'label': 'MATCH'}]},
#  {'text': 'To attract settlers, the Dutch instituted the patroon system in 1628, whereby wealthy Dutchmen (patroons, or patrons) who brought 50 colonists to New Netherland would be awarded swathes of land, along with local political autonomy and rights to participate in the lucrative fur trade.',
#   'ents': [{'start': 46, 'end': -224, 'label': 'MATCH'}]},
#  {'text': 'To attract settlers, the Dutch instituted the patroon system in 1628, whereby wealthy Dutchmen (patroons, or patrons) who brought 50 colonists to New Netherland would be awarded swathes of land, along with local political autonomy and rights to participate in the lucrative fur trade.',
#   'ents': [{'start': 274, 'end': -1, 'label': 'MATCH'}]},
#  {'text': 'In 1639–1640, in an effort to bolster economic growth, the Dutch West India Company relinquished its monopoly over the fur trade, leading to growth in the production and trade of food, timber, tobacco, and slaves (particularly with the Dutch West Indies).In 1647, Peter Stuyvesant began his tenure as the last Director-General of New Netherland.',
#   'ents': [{'start': 119, 'end': -217, 'label': 'MATCH'}]},
#  {'text': 'He instituted regulations on liquor sales, attempted to assert control over th',
#   'ents': [{'start': 29, 'end': -37, 'label': 'MATCH'}]}]

# %%
displacy.render(matched_sents, style='ent', manual=True, jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">With an estimated 2018 population of 8,398,748 distributed over a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     land area
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  of about 302.6 square miles (784 km2), New York is also the most densely populated major city in the United States.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">A global
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     power city
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
# , New York City has been described as the cultural, financial, and media capital of the world, and exerts a significant impact upon commerce, entertainment, research, technology, education, politics, tourism, art, fashion, and sports.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">A global power city, New York City has been described as the cultural, financial, and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     media capital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  of the world, and exerts a significant impact upon commerce, entertainment, research, technology, education, politics, tourism, art, fashion, and sports.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The city and its metropolitan area constitute the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     premier gateway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  for legal immigration to the United States.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">New York City traces its origins to a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     trading post
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  founded by colonists from the Dutch Republic in 1624 on Lower Manhattan; the post was named New Amsterdam in 1626.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Many districts and landmarks in New York City are well known, with the city having three of the world's ten most visited
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     tourist attractions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  in 2013 and receiving a record 62.8 million tourists in 2017.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Times Square, iconic as the world's &quot;heart&quot; and its &quot;Crossroads&quot;, is the brightly illuminated hub of the Broadway Theater District, one of the world's busiest
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     pedestrian intersections
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
# , and a major center of the world's entertainment industry.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Times Square, iconic as the world's &quot;heart&quot; and its &quot;Crossroads&quot;, is the brightly illuminated hub of the Broadway Theater District, one of the world's busiest pedestrian intersections, and a major center of the world's
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     entertainment industry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
# .</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Manhattan's real
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     estate market
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  is among the most expensive in the world.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">New York is home to the largest ethnic Chinese population outside of Asia, with multiple
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     signature Chinatowns
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  developing across the city.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Providing continuous 24/7 service, the New York City Subway is the largest single-operator rapid
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     transit system
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  worldwide, with 472 rail stations.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Providing continuous 24/7 service, the New York City Subway is the largest single-operator rapid transit system worldwide, with 472
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     rail stations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
# .</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Anchored by Wall Street in the Financial District of Lower Manhattan, New York has been called both the most economically powerful city and the leading financial center of the world, and the city is home to the world's two largest
# <mark class="entity" style="backgro

# %%
patterns = [[{'POS' : 'NOUN', 'IS_ALPHA' : True, 'IS_STOP' : False, 'OP' : '+'}]]
matcher = Matcher(nlp.vocab)
matched_sents = []
matched_phrases = []
for pattern in patterns:
    matcher.add('keyword', collect_sents, pattern)

# %%
matches = matcher(nynlp)

# %%
sorted(matched_phrases)
# Out:
# ['Chinatowns',
#  'Dutchmen',
#  'Etymology',
#  'GDP',
#  'History',
#  'Home',
#  'action',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'art',
#  'attractions',
#  'authority',
#  'autonomy',
#  'band',
#  'beads',
#  'bedrock',
#  'belief',
#  'billionaires',
#  'boroughs',
#  'boroughs',
#  'brother',
#  'brother',
#  'capital',
#  'capital',
#  'capital',
#  'capital city',
#  'capitalization',
#  'captain',
#  'center',
#  'center',
#  'center',
#  'center',
#  'centuries',
#  'century',
#  'citadel',
#  'cities',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'claims',
#  'colleges',
#  'colonial',
#  'colonists',
#  'colonists',
#  'colony',
#  'colony',
#  'commerce',
#  'construction',
#  'control',
#  'control',
#  'country',
#  'county',
#  'creativity',
#  'crown',
#  'day',
#  'day',
#  'day',
#  'day',
#  'day',
#  'day exploration',
#  'depth',
#  'depth',
#  'descent',
#  'diplomacy',
#  'districts',
#  'diversity',
#  'diversity',
#  'edge',
#  'education',
#  'effort',
#  'entertainment',
#  'entertainment',
#  'entertainment industry',
#  'entrepreneurship',
#  'era',
#  'estate',
#  'estate market',
#  'exchanges',
#  'expedition',
#  'expedition',
#  'exploration',
#  'explorer',
#  'explorer',
#  'fashion',
#  'feet',
#  'fish',
#  'food',
#  'foundation',
#  'founding',
#  'freedom',
#  'fur',
#  'fur',
#  'fur',
#  'fur trade',
#  'fur trade',
#  'fur trading',
#  'fur trading settlement',
#  'gateway',
#  'glaciation',
#  'glass',
#  'glass beads',
#  'growth',
#  'growth',
#  'guilders',
#  'harbor',
#  'harbors',
#  'headquarters',
#  'heart',
#  'history',
#  'home',
#  'home',
#  'home',
#  'home',
#  'homeland',
#  'honor',
#  'honor',
#  'honor',
#  'hub',
#  'ice',
#  'ice',
#  'ice sheet',
#  'ideals',
#  'immigrants',
#  'immigration',
#  'impact',
#  'industry',
#  'inhabitant',
#  'intersections',
#  'island',
#  'km',
#  'land',
#  'land',
#  'land area',
#  'landmarks',
#  'landmarks',
#  'landmass',
#  'lands',
#  'languages',
#  'law',
#  'leader',
#  'legend',
#  'legend claims',
#  'liberty',
#  'liquor',
#  'liquor sales',
#  'm',
#  'map',
#  'market',
#  'market',
#  'market capitalization',
#  'mate',
#  'media',
#  'media capital',
#  'megacities',
#  'merchant',
#  'mile',
#  'miles',
#  'miles',
#  'millions',
#  'minute',
#  'monopoly',
#  'monopoly',
#  'mouth',
#  'movement',
#  'names',
#  'node',
#  'north',
#  'number',
#  'operator',
#  'order',
#  'origins',
#  'pace',
#  'parks',
#  'patrons',
#  'patroon',
#  'patroon system',
#  'patroons',
#  'peace',
#  'pedestrian',
#  'pedestrian intersections',
#  'pelts',
#  'people',
#  'people',
#  'politics',
#  'population',
#  'population',
#  'population',
#  'population',
#  'population',
#  'portion',
#  'post',
#  'post',
#  'power',
#  'power city',
#  'premier',
#  'premier gateway',
#  'presence',
#  'product',
#  'production',
#  'program',
#  'proprietor',
#  'purchase',
#  'rail',
#  'rail stations',
#  'record',
#  'region',
#  'region',
#  'regulations',
#  'representative',
#  'reputation',
#  'research',
#  'residents',
#  'residents',
#  'retreat',
#  'rights',
#  'river',
#  'river',
#  'rule',
#  'sailing',
#  'sales',
#  'separation',
#  'service',
#  'service',
#  'settlement',
#  'settlement',
#  'settlers',
#  'sheet',
#  'ship',
#  'signature',
#  'signature Chinatowns',
#  'site',
#  'site',
#  'skyscrapers',
#  'skyscrapers',
#  'slaves',
#  'sources',
#  'sports',
#  'state',
#  'state',
#  'stations',
#  'stock',
#  'stock exchanges',
#  'stockade',
#  'success',
#  'surroundings',
#  'survey',
#  'sustainability',
#  'swathes',
#  'symbol',
#  'symbol',
#  'system',
#  'system',
#  'technology',
#  'tenure',
#  'tenure',
#  'term',
#  'territory',
#  'timber',
#  'tip',
#  'tip',
#  'tobacco',
#  'tolerance',
#  'tourism',
#  'tourist',
#  'tourist attractions',
#  'tourists',
#  'trade',
#  'trade',
#  'trade',
#  'trading',
#  'trading',
#  'trading',
#  'trading post',
#  'trading settlement',
#  'transit',
#  'transit system',
#  'tributary',
#  'universities',
#  'universities',
#  'value',
#  'visit',
#  'windes',
#  'winter',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'worth',
#  'years']

# %%
from collections import Counter

# %%
keywords = dict(Counter(matched_phrases))

# %%
keywords
# Out:
# {'city': 23,
#  'population': 5,
#  'land': 2,
#  'land area': 1,
#  'area': 10,
#  'miles': 2,
#  'tip': 2,
#  'state': 2,
#  'center': 4,
#  'world': 19,
#  'landmass': 1,
#  'megacities': 1,
#  'people': 2,
#  'residents': 2,
#  'power': 1,
#  'power city': 1,
#  'media': 1,
#  'media capital': 1,
#  'capital': 3,
#  'impact': 1,
#  'commerce': 1,
#  'entertainment': 2,
#  'research': 1,
#  'technology': 1,
#  'education': 1,
#  'politics': 1,
#  'tourism': 1,
#  'art': 1,
#  'fashion': 1,
#  'sports': 1,
#  'pace': 1,
#  'term': 1,
#  'minute': 1,
#  'Home': 1,
#  'headquarters': 1,
#  'diplomacy': 1,
#  'harbors': 1,
#  'boroughs': 2,
#  'county': 1,
#  'premier': 1,
#  'premier gateway': 1,
#  'gateway': 1,
#  'immigration': 1,
#  'languages': 1,
#  'home': 4,
#  'product': 1,
#  'GDP': 1,
#  'number': 1,
#  'billionaires': 1,
#  'origins': 1,
#  'trading': 3,
#  'trading post': 1,
#  'post': 2,
#  'colonists': 2,
#  'surroundings': 1,
#  'control': 2,
#  'lands': 1,
#  'brother': 2,
#  'country': 1,
#  'millions': 1,
#  'immigrants': 1,
#  'ship': 1,
#  'centuries': 1,
#  'symbol': 2,
#  'ideals': 1,
#  'liberty': 1,
#  'peace': 1,
#  'century': 1,
#  'node': 1,
#  'creativity': 1,
#  'entrepreneurship': 1,
#  'tolerance': 1,
#  'sustainability': 1,
#  'freedom': 1,
#  'diversity': 2,
#  'survey': 1,
#  'cities': 1,
#  'districts': 1,
#  'landmarks': 2,
#  'tourist': 1,
#  'tourist attractions': 1,
#  'attractions': 1,
#  'record': 1,
#  'tourists': 1,
#  'sources': 1,
#  'heart': 1,
#  'hub': 1,
#  'pedestrian': 1,
#  'pedestrian intersections': 1,
#  'intersections': 1,
#  'entertainment industry': 1,
#  'industry': 1,
#  'names': 1,
#  'skyscrapers': 2,
#  'parks': 1,
#  'estate': 1,
#  'estate market': 1,
#  'market': 2,
#  'signature': 1,
#  'signature Chinatowns': 1,
#  'Chinatowns': 1,
#  'service': 2,
#  'operator': 1,
#  'transit': 1,
#  'transit system': 1,
#  'system': 2,
#  'rail': 1,
#  'rail stations': 1,
#  'stations': 1,
#  'colleges': 1,
#  'universities': 2,
#  'stock': 1,
#  'stock exchanges': 1,
#  'exchanges': 1,
#  'market capitalization': 1,
#  'capitalization': 1,
#  'History': 1,
#  'Etymology': 1,
#  'honor': 3,
#  'proprietor': 1,
#  'territory': 1,
#  'history': 1,
#  'glaciation': 1,
#  'years': 1,
#  'region': 2,
#  'edge': 1,
#  'ice': 2,
#  'ice sheet': 1,
#  'sheet': 1,
#  'feet': 1,
#  'm': 1,
#  'depth': 2,
#  'movement': 1,
#  'retreat': 1,
#  'separation': 1,
#  'action': 1,
#  'bedrock': 1,
#  'foundation': 1,
#  'era': 1,
#  'day': 5,
#  'homeland': 1,
#  'portion': 1,
#  'visit': 1,
#  'explorer': 2,
#  'crown': 1,
#  'expedition': 2,
#  'captain': 1,
#  'sailing': 1,
#  'mouth': 1,
#  'map': 1,
#  'mate': 1,
#  'harbor': 1,
#  'windes': 1,
#  'river': 2,
#  'mile': 1,
#  'fish': 1,
#  'km': 1,
#  'north': 1,
#  'site': 2,
#  'capital city': 1,
#  'belief': 1,
#  'tributary': 1,
#  'day exploration': 1,
#  'exploration': 1,
#  'inhabitant': 1,
#  'merchant': 1,
#  'descent': 1,
#  'winter': 1,
#  'pelts': 1,
#  'representative': 1,
#  'rule': 1,
#  'presence': 1,
#  'settlement': 2,
#  'founding': 1,
#  'fur': 3,
#  'fur trading': 1,
#  'fur trading settlement': 1,
#  'trading settlement': 1,
#  'construction': 1,
#  'citadel': 1,
#  'colony': 2,
#  'stockade': 1,
#  'colonial': 1,
#  'island': 1,
#  'band': 1,
#  'value': 1,
#  'guilders': 1,
#  'legend': 1,
#  'legend claims': 1,
#  'claims': 1,
#  'worth': 1,
#  'glass': 1,
#  'glass beads': 1,
#  'beads': 1,
#  'purchase': 1,
#  'settlers': 1,
#  'patroon': 1,
#  'patroon system': 1,
#  'Dutchmen': 1,
#  'patroons': 1,
#  'patrons': 1,
#  'swathes': 1,
#  'autonomy': 1,
#  'rights': 1,
#  'fur trade': 2,
#  'trade': 3,
#  'program': 1,
#  'success': 1,
#  'monopoly': 2,
#  'authority': 1,
#  'effort': 1,
#  'growth': 2,
#  'production': 1,
#  'food': 1,
#  'timber': 1,
#  'tobacco': 1,
#  'slaves': 1,
#  'tenure': 2,
#  'law': 1,
#  'order': 1,
#  'reputation': 1,
#  'leader': 1,
#  'regulations': 1,
#  'liquor': 1,
#  'liquor sales': 1,
#  'sales': 1}

# %%
import math
import re
keywords_cvalues = {}
for keyword in sorted(keywords.keys()):
    parent_terms = list(filter(lambda t: t != keyword and re.match('\\b%s\\b' % keyword, t), keywords.keys()))
    keywords_cvalues[keyword] = keywords[keyword]
    print('TERM: ', keyword, 'PARENT TERMS: ', parent_terms)
    for pt in parent_terms:
        keywords_cvalues[keyword] -= float(keywords[pt])/float(len(parent_terms))
    keywords_cvalues[keyword] *= math.log(len(keyword.split()), 2)
# Out:
# TERM:  Chinatowns PARENT TERMS:  []
# TERM:  Dutchmen PARENT TERMS:  []
# TERM:  Etymology PARENT TERMS:  []
# TERM:  GDP PARENT TERMS:  []
# TERM:  History PARENT TERMS:  []
# TERM:  Home PARENT TERMS:  []
# TERM:  action PARENT TERMS:  []
# TERM:  area PARENT TERMS:  []
# TERM:  art PARENT TERMS:  []
# TERM:  attractions PARENT TERMS:  []
# TERM:  authority PARENT TERMS:  []
# TERM:  autonomy PARENT TERMS:  []
# TERM:  band PARENT TERMS:  []
# TERM:  beads PARENT TERMS:  []
# TERM:  bedrock PARENT TERMS:  []
# TERM:  belief PARENT TERMS:  []
# TERM:  billionaires PARENT TERMS:  []
# TERM:  boroughs PARENT TERMS:  []
# TERM:  brother PARENT TERMS:  []
# TERM:  capital PARENT TERMS:  ['capital city']
# TERM:  capital city PARENT TERMS:  []
# TERM:  capitalization PARENT TERMS:  []
# TERM:  captain PARENT TERMS:  []
# TERM:  center PARENT TERMS:  []
# TERM:  centuries PARENT TERMS:  []
# TERM:  century PARENT TERMS:  []
# TERM:  citadel PARENT TERMS:  []
# TERM:  cities PARENT TERMS:  []
# TERM:  city PARENT TERMS:  []
# TERM:  claims PARENT TERMS:  []
# TERM:  colleges PARENT TERMS:  []
# TERM:  colonial PARENT TERMS:  []
# TERM:  colonists PARENT TERMS:  []
# TERM:  colony PARENT TERMS:  []
# TERM:  commerce PARENT TERMS:  []
# TERM:  construction PARENT TERMS:  []
# TERM:  control PARENT TERMS:  []
# TERM:  country PARENT TERMS:  []
# TERM:  county PARENT TERMS:  []
# TERM:  creativity PARENT TERMS:  []
# TERM:  crown PARENT TERMS:  []
# TERM:  day PARENT TERMS:  ['day exploration']
# TERM:  day exploration PARENT TERMS:  []
# TERM:  depth PARENT TERMS:  []
# TERM:  descent PARENT TERMS:  []
# TERM:  diplomacy PARENT TERMS:  []
# TERM:  districts PARENT TERMS:  []
# TERM:  diversity PARENT TERMS:  []
# TERM:  edge PARENT TERMS:  []
# TERM:  education PARENT TERMS:  []
# TERM:  effort PARENT TERMS:  []
# TERM:  entertainment PARENT TERMS:  ['entertainment industry']
# TERM:  entertainment industry PARENT TERMS:  []
# TERM:  entrepreneurship PARENT TERMS:  []
# TERM:  era PARENT TERMS:  []
# TERM:  estate PARENT TERMS:  ['estate market']
# TERM:  estate market PARENT TERMS:  []
# TERM:  exchanges PARENT TERMS:  []
# TERM:  expedition PARENT TERMS:  []
# TERM:  exploration PARENT TERMS:  []
# TERM:  explorer PARENT TERMS:  []
# TERM:  fashion PARENT TERMS:  []
# TERM:  feet PARENT TERMS:  []
# TERM:  fish PARENT TERMS:  []
# TERM:  food PARENT TERMS:  []
# TERM:  foundation PARENT TERMS:  []
# TERM:  founding PARENT TERMS:  []
# TERM:  freedom PARENT TERMS:  []
# TERM:  fur PARENT TERMS:  ['fur trading', 'fur trading settlement', 'fur trade']
# TERM:  fur trade PARENT TERMS:  []
# TERM:  fur trading PARENT TERMS:  ['fur trading settlement']
# TERM:  fur trading settlement PARENT TERMS:  []
# TERM:  gateway PARENT TERMS:  []
# TERM:  glaciation PARENT TERMS:  []
# TERM:  glass PARENT TERMS:  ['glass beads']
# TERM:  glass beads PARENT TERMS:  []
# TERM:  growth PARENT TERMS:  []
# TERM:  guilders PARENT TERMS:  []
# TERM:  harbor PARENT TERMS:  []
# TERM:  harbors PARENT TERMS:  []
# TERM:  headquarters PARENT TERMS:  []
# TERM:  heart PARENT TERMS:  []
# TERM:  history PARENT TERMS:  []
# TERM:  home PARENT TERMS:  []
# TERM:  homeland PARENT TERMS:  []
# TERM:  honor PARENT TERMS:  []
# TERM:  hub PARENT TERMS:  []
# TERM:  ice PARENT TERMS:  ['ice sheet']
# TERM:  ice sheet PARENT TERMS:  []
# TERM:  ideals PARENT TERMS:  []
# TERM:  immigrants PARENT TERMS:  []
# TERM:  immigration PARENT TERMS:  []
# TERM:  impact PARENT TERMS:  []
# TERM:  industry PARENT TERMS:  []
# TERM:  inhabitant PARENT TERMS:  []
# TERM:  intersections PARENT TERMS:  []
# TERM:  island PARENT TERMS:  []
# TERM:  km PARENT TERMS:  []
# TERM:  land PARENT TERMS:  ['land area']
# TERM:  land area PARENT TERMS:  []
# TERM:  landmarks PARENT TERMS:  []
# TERM:  landmass PARENT TERMS:  []
# TERM:  lands PARENT TERMS:  []
# TERM:  languages PARENT TERMS:  []
# TERM:  law PARENT TERMS:  []
# TERM:  leader PARENT TERMS:  []
# TERM:  legend PARENT TERMS:  ['legend claims']
# TERM:  legend claims PARENT TERMS:  []
# TERM:  liberty PARENT TERMS:  []
# TERM:  liquor PARENT TERMS:  ['liquor sales']
# TERM:  liquor sales PARENT TERMS:  []
# TERM:  m PARENT TERMS:  []
# TERM:  map PARENT TERMS:  []
# TERM:  market PARENT TERMS:  ['market capitalization']
# TERM:  market capitalization PARENT TERMS:  []
# TERM:  mate PARENT TERMS:  []
# TERM:  media PARENT TERMS:  ['media capital']
# TERM:  media capital PARENT TERMS:  []
# TERM:  megacities PARENT TERMS:  []
# TERM:  merchant PARENT TERMS:  []
# TERM:  mile PARENT TERMS:  []
# TERM:  miles PARENT TERMS:  []
# TERM:  millions PARENT TERMS:  []
# TERM:  minute PARENT TERMS:  []
# TERM:  monopoly PARENT TERMS:  []
# TERM:  mouth PARENT TERMS:  []
# TERM:  movement PARENT TERMS:  []
# TERM:  names PARENT TERMS:  []
# TERM:  node PARENT TERMS:  []
# TERM:  north PARENT TERMS:  []
# TERM:  number PARENT TERMS:  []
# TERM:  operator PARENT TERMS:  []
# TERM:  order PARENT TERMS:  []
# TERM:  origins PARENT TERMS:  []
# TERM:  pace PARENT TERMS:  []
# TERM:  parks PARENT TERMS:  []
# TERM:  patrons PARENT TERMS:  []
# TERM:  patroon PARENT TERMS:  ['patroon system']
# TERM:  patroon system PARENT TERMS:  []
# TERM:  patroons PARENT TERMS:  []
# TERM:  peace PARENT TERMS:  []
# TERM:  pedestrian PARENT TERMS:  ['pedestrian intersections']
# TERM:  pedestrian intersections PARENT TERMS:  []
# TERM:  pelts PARENT TERMS:  []
# TERM:  people PARENT TERMS:  []
# TERM:  politics PARENT TERMS:  []
# TERM:  population PARENT TERMS:  []
# TERM:  portion PARENT TERMS:  []
# TERM:  post PARENT TERMS:  []
# TERM:  power PARENT TERMS:  ['power city']
# TERM:  power city PARENT TERMS:  []
# TERM:  premier PARENT TERMS:  ['premier gateway']
# TERM:  premier gateway PARENT TERMS:  []
# TERM:  presence PARENT TERMS:  []
# TERM:  product PARENT TERMS:  []
# TERM:  production PARENT TERMS:  []
# TERM:  program PARENT TERMS:  []
# TERM:  proprietor PARENT TERMS:  []
# TERM:  purchase PARENT TERMS:  []
# TERM:  rail PARENT TERMS:  ['rail stations']
# TERM:  rail stations PARENT TERMS:  []
# TERM:  record PARENT TERMS:  []
# TERM:  region PARENT TERMS:  []
# TERM:  regulations PARENT TERMS:  []
# TERM:  representative PARENT TERMS:  []
# TERM:  reputation PARENT TERMS:  []
# TERM:  research PARENT TERMS:  []
# TERM:  residents PARENT TERMS:  []
# TERM:  retreat PARENT TERMS:  []
# TERM:  rights PARENT TERMS:  []
# TERM:  river PARENT TERMS:  []
# TERM:  rule PARENT TERMS:  []
# TERM:  sailing PARENT TERMS:  []
# TERM:  sales PARENT TERMS:  []
# TERM:  separation PARENT TERMS:  []
# TERM:  service PARENT TERMS:  []
# TERM:  settlement PARENT TERMS:  []
# TERM:  settlers PARENT TERMS:  []
# TERM:  sheet PARENT TERMS:  []
# TERM:  ship PARENT TERMS:  []
# TERM:  signature PARENT TERMS:  ['signature Chinatowns']
# TERM:  signature Chinatowns PARENT TERMS:  []
# TERM:  site PARENT TERMS:  []
# TERM:  skyscrapers PARENT TERMS:  []
# TERM:  slaves PARENT TERMS:  []
# TERM:  sources PARENT TERMS:  []
# TERM:  sports PARENT TERMS:  []
# TERM:  state PARENT TERMS:  []
# TERM:  stations PARENT TERMS:  []
# TERM:  stock PARENT TERMS:  ['stock exchanges']
# TERM:  stock exchanges PARENT TERMS:  []
# TERM:  stockade PARENT TERMS:  []
# TERM:  success PARENT TERMS:  []
# TERM:  surroundings PARENT TERMS:  []
# TERM:  survey PARENT TERMS:  []
# TERM:  sustainability PARENT TERMS:  []
# TERM:  swathes PARENT TERMS:  []
# TERM:  symbol PARENT TERMS:  []
# TERM:  system PARENT TERMS:  []
# TERM:  technology PARENT TERMS:  []
# TERM:  tenure PARENT TERMS:  []
# TERM:  term PARENT TERMS:  []
# TERM:  territory PARENT TERMS:  []
# TERM:  timber PARENT TERMS:  []
# TERM:  tip PARENT TERMS:  []
# TERM:  tobacco PARENT TERMS:  []
# TERM:  tolerance PARENT TERMS:  []
# TERM:  tourism PARENT TERMS:  []
# TERM:  tourist PARENT TERMS:  ['tourist attractions']
# TERM:  tourist attractions PARENT TERMS:  []
# TERM:  tourists PARENT TERMS:  []
# TERM:  trade PARENT TERMS:  []
# TERM:  trading PARENT TERMS:  ['trading post', 'trading settlement']
# TERM:  trading post PARENT TERMS:  []
# TERM:  trading settlement PARENT TERMS:  []
# TERM:  transit PARENT TERMS:  ['transit system']
# TERM:  transit system PARENT TERMS:  []
# TERM:  tributary PARENT TERMS:  []
# TERM:  universities PARENT TERMS:  []
# TERM:  value PARENT TERMS:  []
# TERM:  visit PARENT TERMS:  []
# TERM:  windes PARENT TERMS:  []
# TERM:  winter PARENT TERMS:  []
# TERM:  world PARENT TERMS:  []
# TERM:  worth PARENT TERMS:  []
# TERM:  years PARENT TERMS:  []

# %%
keywords_cvalues
# Out:
# {'Chinatowns': 0.0,
#  'Dutchmen': 0.0,
#  'Etymology': 0.0,
#  'GDP': 0.0,
#  'History': 0.0,
#  'Home': 0.0,
#  'action': 0.0,
#  'area': 0.0,
#  'art': 0.0,
#  'attractions': 0.0,
#  'authority': 0.0,
#  'autonomy': 0.0,
#  'band': 0.0,
#  'beads': 0.0,
#  'bedrock': 0.0,
#  'belief': 0.0,
#  'billionaires': 0.0,
#  'boroughs': 0.0,
#  'brother': 0.0,
#  'capital': 0.0,
#  'capital city': 1.0,
#  'capitalization': 0.0,
#  'captain': 0.0,
#  'center': 0.0,
#  'centuries': 0.0,
#  'century': 0.0,
#  'citadel': 0.0,
#  'cities': 0.0,
#  'city': 0.0,
#  'claims': 0.0,
#  'colleges': 0.0,
#  'colonial': 0.0,
#  'colonists': 0.0,
#  'colony': 0.0,
#  'commerce': 0.0,
#  'construction': 0.0,
#  'control': 0.0,
#  'country': 0.0,
#  'county': 0.0,
#  'creativity': 0.0,
#  'crown': 0.0,
#  'day': 0.0,
#  'day exploration': 1.0,
#  'depth': 0.0,
#  'descent': 0.0,
#  'diplomacy': 0.0,
#  'districts': 0.0,
#  'diversity': 0.0,
#  'edge': 0.0,
#  'education': 0.0,
#  'effort': 0.0,
#  'entertainment': 0.0,
#  'entertainment industry': 1.0,
#  'entrepreneurship': 0.0,
#  'era': 0.0,
#  'estate': 0.0,
#  'estate market': 1.0,
#  'exchanges': 0.0,
#  'expedition': 0.0,
#  'exploration': 0.0,
#  'explorer': 0.0,
#  'fashion': 0.0,
#  'feet': 0.0,
#  'fish': 0.0,
#  'food': 0.0,
#  'foundation': 0.0,
#  'founding': 0.0,
#  'freedom': 0.0,
#  'fur': 0.0,
#  'fur trade': 2.0,
#  'fur trading': 0.0,
#  'fur trading settlement': 1.5849625007211563,
#  'gateway': 0.0,
#  'glaciation': 0.0,
#  'glass': 0.0,
#  'glass beads': 1.0,
#  'growth': 0.0,
#  'guilders': 0.0,
#  'harbor': 0.0,
#  'harbors': 0.0,
#  'headquarters': 0.0,
#  'heart': 0.0,
#  'history': 0.0,
#  'home': 0.0,
#  'homeland': 0.0,
#  'honor': 0.0,
#  'hub': 0.0,
#  'ice': 0.0,
#  'ice sheet': 1.0,
#  'ideals': 0.0,
#  'immigrants': 0.0,
#  'immigration': 0.0,
#  'impact': 0.0,
#  'industry': 0.0,
#  'inhabitant': 0.0,
#  'intersections': 0.0,
#  'island': 0.0,
#  'km': 0.0,
#  'land': 0.0,
#  'land area': 1.0,
#  'landmarks': 0.0,
#  'landmass': 0.0,
#  'lands': 0.0,
#  'languages': 0.0,
#  'law': 0.0,
#  'leader': 0.0,
#  'legend': 0.0,
#  'legend claims': 1.0,
#  'liberty': 0.0,
#  'liquor': 0.0,
#  'liquor sales': 1.0,
#  'm': 0.0,
#  'map': 0.0,
#  'market': 0.0,
#  'market capitalization': 1.0,
#  'mate': 0.0,
#  'media': 0.0,
#  'media capital': 1.0,
#  'megacities': 0.0,
#  'merchant': 0.0,
#  'mile': 0.0,
#  'miles': 0.0,
#  'millions': 0.0,
#  'minute': 0.0,
#  'monopoly': 0.0,
#  'mouth': 0.0,
#  'movement': 0.0,
#  'names': 0.0,
#  'node': 0.0,
#  'north': 0.0,
#  'number': 0.0,
#  'operator': 0.0,
#  'order': 0.0,
#  'origins': 0.0,
#  'pace': 0.0,
#  'parks': 0.0,
#  'patrons': 0.0,
#  'patroon': 0.0,
#  'patroon system': 1.0,
#  'patroons': 0.0,
#  'peace': 0.0,
#  'pedestrian': 0.0,
#  'pedestrian intersections': 1.0,
#  'pelts': 0.0,
#  'people': 0.0,
#  'politics': 0.0,
#  'population': 0.0,
#  'portion': 0.0,
#  'post': 0.0,
#  'power': 0.0,
#  'power city': 1.0,
#  'premier': 0.0,
#  'premier gateway': 1.0,
#  'presence': 0.0,
#  'product': 0.0,
#  'production': 0.0,
#  'program': 0.0,
#  'proprietor': 0.0,
#  'purchase': 0.0,
#  'rail': 0.0,
#  'rail stations': 1.0,
#  'record': 0.0,
#  'region': 0.0,
#  'regulations': 0.0,
#  'representative': 0.0,
#  'reputation': 0.0,
#  'research': 0.0,
#  'residents': 0.0,
#  'retreat': 0.0,
#  'rights': 0.0,
#  'river': 0.0,
#  'rule': 0.0,
#  'sailing': 0.0,
#  'sales': 0.0,
#  'separation': 0.0,
#  'service': 0.0,
#  'settlement': 0.0,
#  'settlers': 0.0,
#  'sheet': 0.0,
#  'ship': 0.0,
#  'signature': 0.0,
#  'signature Chinatowns': 1.0,
#  'site': 0.0,
#  'skyscrapers': 0.0,
#  'slaves': 0.0,
#  'sources': 0.0,
#  'sports': 0.0,
#  'state': 0.0,
#  'stations': 0.0,
#  'stock': 0.0,
#  'stock exchanges': 1.0,
#  'stockade': 0.0,
#  'success': 0.0,
#  'surroundings': 0.0,
#  'survey': 0.0,
#  'sustainability': 0.0,
#  'swathes': 0.0,
#  'symbol': 0.0,
#  'system': 0.0,
#  'technology': 0.0,
#  'tenure': 0.0,
#  'term': 0.0,
#  'territory': 0.0,
#  'timber': 0.0,
#  'tip': 0.0,
#  'tobacco': 0.0,
#  'tolerance': 0.0,
#  'tourism': 0.0,
#  'tourist': 0.0,
#  'tourist attractions': 1.0,
#  'tourists': 0.0,
#  'trade': 0.0,
#  'trading': 0.0,
#  'trading post': 1.0,
#  'trading settlement': 1.0,
#  'transit': 0.0,
#  'transit system': 1.0,
#  'tributary': 0.0,
#  'universities': 0.0,
#  'value': 0.0,
#  'visit': 0.0,
#  'windes': 0.0,
#  'winter': 0.0,
#  'world': 0.0,
#  'worth': 0.0,
#  'years': 0.0}

# %%
best_keywords = []
for keyword in sorted(keywords_cvalues, key=keywords_cvalues.get, reverse = True)[:10]:
    best_keywords.append([keyword, keywords_cvalues[keyword]])

# %%
best_keywords
# Out:
# [['fur trade', 2.0],
#  ['fur trading settlement', 1.5849625007211563],
#  ['capital city', 1.0],
#  ['day exploration', 1.0],
#  ['entertainment industry', 1.0],
#  ['estate market', 1.0],
#  ['glass beads', 1.0],
#  ['ice sheet', 1.0],
#  ['land area', 1.0],
#  ['legend claims', 1.0]]

# %%
import wikipedia
import spacy
from spacy.matcher import Matcher
import math
import re
from collections import Counter

nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner', 'textcat'])

matched_phrases = []
def collect_sents(matcher, doc, i, matches):
    match_id, start, end = matches[i]
    span = doc[start : end]
    matched_phrases.append(span.lemma_)
    
patterns = [[{'POS' : 'NOUN', 'IS_ALPHA' : True, 'IS_STOP' : False, 'OP' : '+'}]]
matcher = Matcher(nlp.vocab)
for pattern in patterns:
    matcher.add('keyword', collect_sents, pattern)
    
def extract_keywords_wikipedia(pagename, num_keywords):
    global matched_phrases
    page = wikipedia.page(pagename)
    pagenlp = nlp(page.content)
    matched_phrases = []
    matches = matcher(pagenlp)
    keywords = dict(Counter(matched_phrases).most_common(100))
    keywords_cvalues = {}
    for keyword in sorted(keywords.keys()):
        parent_terms = list(filter(lambda t: t != keyword and re.match('\\b%s\\b' % keyword, t), keywords.keys()))
        keywords_cvalues[keyword] = keywords[keyword]
        for pt in parent_terms:
            keywords_cvalues[keyword] -= float(keywords[pt])/float(len(parent_terms))
        keywords_cvalues[keyword] *= 1 + math.log(len(keyword.split()), 2) 
        
    best_keywords = []
    for keyword in sorted(keywords_cvalues, key=keywords_cvalues.get, reverse = True)[:num_keywords]:
        best_keywords.append([keyword, keywords_cvalues[keyword]])
    return best_keywords

# %%
extract_keywords_wikipedia('New York City', 10)
# Out:
# [['city', 232.0],
#  ['world', 79.0],
#  ['population', 56.0],
#  ['area', 52.0],
#  ['system', 40.0],
#  ['home', 37.0],
#  ['park', 35.0],
#  ['year', 28.0],
#  ['center', 23.0],
#  ['immigrant', 23.0]]

# %%
extract_keywords_wikipedia('Python (programming language)', 10)
# Out:
# [['language', 65.0],
#  ['programming language', 32.0],
#  ['code', 30.0],
#  ['object', 28.0],
#  ['statement', 28.0],
#  ['expression', 26.0],
#  ['type', 22.0],
#  ['library', 20.0],
#  ['division', 19.0],
#  ['operator', 19.0]]

# %%
extract_keywords_wikipedia('Artificial Intelligence', 10)
# Out:
# [['intelligence', 103.0],
#  ['machine', 85.0],
#  ['problem', 74.0],
#  ['system', 61.0],
#  ['network', 55.0],
#  ['research', 47.0],
#  ['knowledge', 43.0],
#  ['learning', 42.0],
#  ['computer', 41.0],
#  ['algorithm', 40.0]]
